# %%
import pandas as pd
df = pd.read_csv("bos_2013csvfile.csv", sep=";")
df = df[df["premium_basis"] == 'Premium Segment']
df = df[['kmean15','glvt_reputation','glvt_workmanship','glvt_safety','glvt_quality','glvt_performance','glvt_technology','glvt_riding_comfort','glvt_roadholding','glvt_interior_styling','glvt_silence','glvt_dependability','glvt_self_expression','glvt_exterior_styling','glvt_roominess','glvt_storage','glvt_versatility','glvt_environmental_friendliness','glvt_economical','glvt_value_for_money','glvt_ease_of_entry','glvt_visibility','glvt_smoothness','glvt_standard_equipment','glvt_instruments','glvt_show_off','glvt_front_seat','glvt_rear_seat','glvt_hvac','glvt_storage_small_items','glvt_maneuverability','glvt_traditional_styling','glvt_high_driving_position','glvt_transport_large_items','glvt_seat_versatility','glvt_personal_space','glvt_fuel_economy','glvt_least_expensive_car']]
df = df.sort_values(by='kmean15')

cols_to_group=list(df.columns)
cols_to_group.remove('kmean15')
print(cols_to_group)
df2 = df.groupby('kmean15')[cols_to_group].mean()

#df2

#df2.to_csv("clu_15_pur_averages.csv", sep=",")

# %%
#import pandas as pd
#df = pd.read_csv("clu_15_pur_SA_dummy_averages.csv", sep=",")
cols_to_group=list(df.columns)
cols_to_group.remove('clu_15_pur')
df2 = df.groupby('clu_15_pur')[cols_to_group].mean()

# %%
for index, row in df2.iterrows():
    sorted_list = sorted(row.tolist().copy(), reverse=True)
    u_list = row.tolist()
    indices = []
    for i in sorted_list[:3]:
        indices.append(u_list.index(i))
    print(indices)
    for i in range(len(row)):
        if i not in indices:
            row[i] = None

#            
df2.to_csv("clu_15_pur_SA_dummy_averages_only_highest.csv", sep=",")
# Out:
# [32, 11, 54]
# [49, 2, 33]
# [13, 16, 53]
# [5, 50, 20]
# [22, 41, 24]
# [8, 36, 47]
# [34, 22, 44]
# [53, 5, 0]
# [44, 12, 23]
# [34, 39, 30]
# [22, 54, 38]
# [19, 13, 36]
# [42, 17, 35]

# %%
df2
# Out:
#             SA40C - M Carbondach  SA715 - M Aerodynamikpaket  \
# clu_15_pur
# 1                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
# 5                            NaN                         NaN
# 6                            NaN                         NaN
# 7                            NaN                         NaN
# 8                            NaN                         NaN
# 10                      95.68126                         NaN
# 11                           NaN                         NaN
# 12                           NaN                         NaN
# 13                           NaN                         NaN
# 14                           NaN                         NaN
# 15                           NaN                         NaN
#
#             SA71A - M Sport X Exterieurpaket  SA71C - M Carbon Exterieurpaket  \
# clu_15_pur
# 1                                        NaN                              NaN
# 3                                  96.625813                              NaN
# 4                                        NaN                              NaN
# 5                                        NaN                              NaN
# 6                                        NaN                              NaN
# 7                                        NaN                              NaN
# 8                                        NaN                              NaN
# 10                                       NaN                              NaN
# 11                                       NaN                              NaN
# 12                                       NaN                              NaN
# 13                                       NaN                              NaN
# 14                                       NaN                              NaN
# 15                                       NaN                              NaN
#
#             SA754 - M Heckspoiler  \
# clu_15_pur
# 1                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 10                            NaN
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
#
#             SA760 - BMW Individual Hochglanz Shadow Line  \
# clu_15_pur
# 1                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                              99.405508
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 10                                             95.721525
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
#
#             SA33T - M Technik Paket  SA7GY - Modell V12 Excellence  \
# clu_15_pur
# 1                               NaN                            NaN
# 3                               NaN                            NaN
# 4                               NaN                            NaN
# 5                               NaN                            NaN
# 6                               NaN                            NaN
# 7                               NaN                            NaN
# 8                               NaN                            NaN
# 10                              NaN                            NaN
# 11                              NaN                            NaN
# 12                              NaN                            NaN
# 13                              NaN                            NaN
# 14                              NaN                            NaN
# 15                              NaN                            NaN
#
#             SA7GZ - Executive Lounge  SA7HN - John Cooper Works Paket  \
# clu_15_pur
# 1                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
# 5                                NaN                              NaN
# 6                                NaN                              NaN
# 7                          99.560742                              NaN
# 8                                NaN                              NaN
# 10                               NaN                              NaN
# 11                               NaN                              NaN
# 12                               NaN                              NaN
# 13                               NaN                              NaN
# 14                               NaN                              NaN
# 15                               NaN                              NaN
#
#                              ...                    \
# clu_15_pur                   ...
# 1                            ...
# 3                            ...
# 4                            ...
# 5                            ...
# 6                            ...
# 7                            ...
# 8                            ...
# 10                           ...
# 11                           ...
# 12                           ...
# 13                           ...
# 14                           ...
# 15                           ...
#
#             SA7S6 - Interieurdesign Pure Experience  \
# clu_15_pur
# 1                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15                                              NaN
#
#             SAXC4 - BMW Individual Komposition  \
# clu_15_pur
# 1                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 10                                         NaN
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
#
#             SAXC5 - BMW Individual Komposition mit M Sport Umfängen  \
# clu_15_pur
# 1                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
# 6                                                         NaN
# 7                                                     98.2948
# 8                                                         NaN
# 10                                                        NaN
# 11                                                        NaN
# 12                                                        NaN
# 13                                                        NaN
# 14                                                        NaN
# 15                                                        NaN
#
#             SA1MD - M Carbon Motorabdeckung  \
# clu_15_pur
# 1                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
#
#             SA4AW - Instrumententafel in Sensatec  \
# clu_15_pur
# 1                                             NaN
# 3                                       99.768405
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
#
#             SA4FG - Sicherheitsgurt BMW i Blau  SA4GQ - M Sicherheitsgurte  \
# clu_15_pur
# 1                                          NaN                         NaN
# 3                                          NaN                         NaN
# 4                                          NaN                         NaN
# 5                                     99.23012                         NaN
# 6                                          NaN                         NaN
# 7                                          NaN                         NaN
# 8                                          NaN                         NaN
# 10                                         NaN                         NaN
# 11                                         NaN                         NaN
# 12                                         NaN                         NaN
# 13                                         NaN                         NaN
# 14                                         NaN                         NaN
# 15                                         NaN                         NaN
#
#             SA4KS - Kontraststeppung  \
# clu_15_pur
# 1                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 10                               NaN
# 11                               NaN
# 12                               NaN
# 13                               NaN
# 14                               NaN
# 15                               NaN
#
#             SA4M5 - BMW Individual Instrumententafel lederbezogen  \
# clu_15_pur
# 1                                                         NaN
# 3                                                         NaN
# 4                                                   82.703573
# 5                                                         NaN
# 6                                                         NaN
# 7                                                         NaN
# 8                                                         NaN
# 10                                                  96.341931
# 11                                                        NaN
# 12                                                        NaN
# 13                                                        NaN
# 14                                                        NaN
# 15                                                        NaN
#
#             SA4ND - Instrumententafel lederbezogen
# clu_15_pur
# 1                                        92.562524
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                              NaN
# 10                                             NaN
# 11                                             NaN
# 12                                             NaN
# 13                                       96.414254
# 14                                             NaN
# 15                                             NaN
#
# [13 rows x 55 columns]

# %%
import pandas as pd
df = pd.read_csv("clu_15_pur_SA_dummy_averages.csv", sep=",")
cols_to_group=list(df.columns)
cols_to_group.remove('clu_15_pur')
df2 = df.groupby('clu_15_pur')[cols_to_group].mean()
